# %% [markdown]
# 下载分类数据集

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 从github下载该项目的zip压缩包

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 直接解压，打开data_set文件夹下的md文档，根据md文档中的链接下载数据集

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 将数据集解压，然后使用脚本文件对数据集进行划分

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 将脚本文件移到该文件夹下，按shift键，然后鼠标右键，选择“在此处打开Powershell窗口”

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 输入 python .\split_data.py 指令执行 split_data.py 脚本，但是出现错误，应该是没有设置python的环境变量

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 最终还是使用pycharm来运行该脚本

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 执行成功之后的文件夹内容结构

# %% [markdown]
# ![image.png](attachment:image.png)
