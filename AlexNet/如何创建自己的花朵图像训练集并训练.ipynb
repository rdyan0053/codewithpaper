# %% [markdown]
# 首先进入flower_photos文件夹下

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  把里面所有文件都删除，其中每个文件夹对应的就是一个类别的图片文件

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 然后直接调用脚本文件，进行划分处理

# %% [markdown]
# ![image.png](attachment:image.png)
