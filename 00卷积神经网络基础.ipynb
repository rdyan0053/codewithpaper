# %% [markdown]
# # 卷积神经网络CNN

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 卷积神经网络发展

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 激活函数（以sigmod和relu为例）

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 卷积矩阵的计算

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 池化层（以MaxPooling下采样层为例）

# %% [markdown]
# ![image.png](attachment:image.png)
